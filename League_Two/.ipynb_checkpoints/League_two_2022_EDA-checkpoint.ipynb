# %% [markdown]
# # 2022 League Two EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge, RidgeCV, Lasso, \
LassoCV, ElasticNet, ElasticNetCV
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVR
from sklearn.decomposition import PCA

# %%
team_stats = pd.read_csv('../footy_data/league_two_teams_2022.csv')
games = pd.read_csv('../footy_data/league_two_games_2022.csv')

# %%
games = games[0:60]
games
#Played matches
# Out:
#      timestamp              date_GMT      status  attendance  \
# 0   1628344800  Aug 07 2021 - 2:00pm    complete         NaN
# 1   1628344800  Aug 07 2021 - 2:00pm    complete         NaN
# 2   1628344800  Aug 07 2021 - 2:00pm    complete         NaN
# 3   1628344800  Aug 07 2021 - 2:00pm    complete         NaN
# 4   1628344800  Aug 07 2021 - 2:00pm    complete         NaN
# 5   1628344800  Aug 07 2021 - 2:00pm    complete         NaN
# 6   1628344800  Aug 07 2021 - 2:00pm    complete         NaN
# 7   1628344800  Aug 07 2021 - 2:00pm    complete         NaN
# 8   1628344800  Aug 07 2021 - 2:00pm    complete         NaN
# 9   1628344800  Aug 07 2021 - 2:00pm    complete         NaN
# 10  1628344800  Aug 07 2021 - 2:00pm    complete         NaN
# 11  1628345700  Aug 07 2021 - 2:15pm    complete         NaN
# 12  1628949600  Aug 14 2021 - 2:00pm    complete         NaN
# 13  1628949600  Aug 14 2021 - 2:00pm    complete         NaN
# 14  1628949600  Aug 14 2021 - 2:00pm    complete         NaN
# 15  1628949600  Aug 14 2021 - 2:00pm    complete         NaN
# 16  1628949600  Aug 14 2021 - 2:00pm    complete         NaN
# 17  1628949600  Aug 14 2021 - 2:00pm    complete         NaN
# 18  1628949600  Aug 14 2021 - 2:00pm    complete         NaN
# 19  1628949600  Aug 14 2021 - 2:00pm    complete         NaN
# 20  1628949600  Aug 14 2021 - 2:00pm    complete         NaN
# 21  1628949600  Aug 14 2021 - 2:00pm    complete         NaN
# 22  1628949600  Aug 14 2021 - 2:00pm    complete         NaN
# 23  1629225900  Aug 17 2021 - 6:45pm    complete         NaN
# 24  1629225900  Aug 17 2021 - 6:45pm    complete         NaN
# 25  1629225900  Aug 17 2021 - 6:45pm    complete         NaN
# 26  1629225900  Aug 17 2021 - 6:45pm    complete         NaN
# 27  1629225900  Aug 17 2021 - 6:45pm    complete         NaN
# 28  1629225900  Aug 17 2021 - 6:45pm    complete         NaN
# 29  1629225900  Aug 17 2021 - 6:45pm    complete         NaN
# 30  1629225900  Aug 17 2021 - 6:45pm    complete         NaN
# 31  1629225900  Aug 17 2021 - 6:45pm    complete         NaN
# 32  1629554400  Aug 21 2021 - 2:00pm    complete         NaN
# 33  1629554400  Aug 21 2021 - 2:00pm    complete         NaN
# 34  1629554400  Aug 21 2021 - 2:00pm    complete         NaN
# 35  1629554400  Aug 21 2021 - 2:00pm    complete         NaN
# 36  1629554400  Aug 21 2021 - 2:00pm    complete         NaN
# 37  1629554400  Aug 21 2021 - 2:00pm    complete         NaN
# 38  1629554400  Aug 21 2021 - 2:00pm    complete         NaN
# 39  1629554400  Aug 21 2021 - 2:00pm    complete         NaN
# 40  1629554400  Aug 21 2021 - 2:00pm    complete         NaN
# 41  1629554400  Aug 21 2021 - 2:00pm    complete         NaN
# 42  1629554400  Aug 21 2021 - 2:00pm    complete         NaN
# 43  1629554400  Aug 21 2021 - 2:00pm    complete         NaN
# 44  1629830700  Aug 24 2021 - 6:45pm    complete         NaN
# 45  1630089900  Aug 27 2021 - 6:45pm    complete         NaN
# 46  1630159200  Aug 28 2021 - 2:00pm    complete         NaN
# 47  1630159200  Aug 28 2021 - 2:00pm    complete         NaN
# 48  1630159200  Aug 28 2021 - 2:00pm    complete         NaN
# 49  1630159200  Aug 28 2021 - 2:00pm    complete         NaN
# 50  1630159200  Aug 28 2021 - 2:00pm    complete         NaN
# 51  1630159200  Aug 28 2021 - 2:00pm    complete         NaN
# 52  1630159200  Aug 28 2021 - 2:00pm    complete         NaN
# 53  1630159200  Aug 28 2021 - 2:00pm    complete         NaN
# 54  1630159200  Aug 28 2021 - 2:00pm    complete         NaN
# 55  1630159200  Aug 28 2021 - 2:00pm    complete         NaN
# 56  1630159200  Aug 28 2021 - 2:00pm    complete         NaN
# 57  1630764000  Sep 04 2021 - 2:00pm  incomplete         NaN
# 58  1630764000  Sep 04 2021 - 2:00pm  incomplete         NaN
# 59  1630764000  Sep 04 2021 - 2:00pm  incomplete         NaN
#
#          home_team_name       away_team_name             referee  Game Week  \
# 0           Exeter City        Bradford City      Samuel Allison          1
# 1   Forest Green Rovers        Sutton United          James Bell          1
# 2        Harrogate Town             Rochdale     Anthony Coggins          1
# 3     Hartlepool United         Crawley Town        Scott Oldham          1
# 4        Mansfield Town       Bristol Rovers        Joshua Smith          1
# 5      Northampton Town            Port Vale        Simon Mather          1
# 6       Oldham Athletic       Newport County           Tom Nield          1
# 7          Salford City        Leyton Orient      Andrew Kitchen          1
# 8     Scunthorpe United         Swindon Town         Sam Purkiss          1
# 9             Stevenage               Barrow        James Oldham          1
# 10      Tranmere Rovers              Walsall          Carl Brook          1
# 11      Carlisle United    Colchester United        Peter Wright          1
# 12               Barrow    Hartlepool United     Darren Drysdale          2
# 13        Bradford City      Oldham Athletic        Steve Martin          2
# 14       Bristol Rovers            Stevenage         Paul Howard          2
# 15    Colchester United     Northampton Town       Trevor Kettle          2
# 16        Leyton Orient          Exeter City          Tom Reeves          2
# 17            Port Vale      Tranmere Rovers         Andy Haines          2
# 18             Rochdale    Scunthorpe United          Martin Coy          2
# 19         Swindon Town      Carlisle United          Carl Brook          2
# 20              Walsall  Forest Green Rovers        Simon Mather          2
# 21         Salford City        Sutton United      Samuel Barrott         31
# 22       Mansfield Town       Newport County   Anthony Backhouse         33
# 23               Barrow          Exeter City      Andrew Kitchen          3
# 24        Bradford City            Stevenage          Martin Coy          3
# 25       Bristol Rovers      Oldham Athletic         Sam Purkiss          3
# 26    Colchester United       Mansfield Town      Samuel Allison          3
# 27         Crawley Town         Salford City          David Rock          3
# 28            Port Vale      Carlisle United         Paul Howard          3
# 29             Rochdale  Forest Green Rovers         Andy Haines          3
# 30         Swindon Town      Tranmere Rovers          John Busby          3
# 31              Walsall    Scunthorpe United         Craig Hicks          3
# 32      Carlisle United        Leyton Orient       Robert Madley          4
# 33          Exeter City       Bristol Rovers     Chris Sarginson          4
# 34  Forest Green Rovers         Crawley Town       Leigh Doughty          4
# 35       Harrogate Town               Barrow       Trevor Kettle          4
# 36    Hartlepool United              Walsall       Declan Bourne          4
# 37       Mansfield Town        Bradford City        Scott Oldham          4
# 38     Northampton Town             Rochdale          Carl Brook          4
# 39      Oldham Athletic    Colchester United      Samuel Barrott          4
# 40         Salford City         Swindon Town          Tom Reeves          4
# 41    Scunthorpe United        Sutton United          Ross Joyce          4
# 42            Stevenage            Port Vale         Will Finnie          4
# 43      Tranmere Rovers       Newport County           Rob Lewis          4
# 44        Leyton Orient       Harrogate Town           Neil Hair          3
# 45             Rochdale    Colchester United       Rebecca Welch          5
# 46               Barrow       Bristol Rovers          Ross Joyce          5
# 47         Crawley Town     Northampton Town          Lee Swabey          5
# 48  Forest Green Rovers            Port Vale  Charles Breakspear          5
# 49       Harrogate Town          Exeter City     Seb Stockbridge          5
# 50    Hartlepool United      Carlisle United        Andy Woolmer          5
# 51        Leyton Orient        Bradford City        Simon Mather          5
# 52         Salford City       Newport County         Ben Speedie          5
# 53    Scunthorpe United      Tranmere Rovers       Trevor Kettle          5
# 54        Sutton United      Oldham Athletic     Darren Drysdale          5
# 55         Swindon Town       Mansfield Town       Robert Madley          5
# 56              Walsall            Stevenage      Andrew Kitchen          5
# 57        Bradford City              Walsall                 NaN          6
# 58       Bristol Rovers         Crawley Town                 NaN          6
# 59      Carlisle United         Salford City                 NaN          6
#
#     Pre-Match PPG (Home)  Pre-Match PPG (Away)  ...  odds_ft_home_team_win  \
# 0                   0.00                   0.0  ...                   2.55
# 1                   0.00                   0.0  ...                   1.83
# 2                   0.00                   0.0  ...                   2.20
# 3                   0.00                   0.0  ...                   2.20
# 4                   0.00                   0.0  ...                   2.35
# 5                   0.00                   0.0  ...                   2.30
# 6                   0.00                   0.0  ...                   3.05
# 7                   0.00                   0.0  ...                   1.95
# 8                   0.00                   0.0  ...                   2.65
# 9                   0.00                   0.0  ...                   2.25
# 10                  0.00                   0.0  ...                   2.00
# 11                  0.00                   0.0  ...                   2.45
# 12                  0.00                   0.0  ...                   2.05
# 13                  0.00                   0.0  ...                   1.77
# 14                  0.00                   0.0  ...                   2.25
# 15                  0.00                   0.0  ...                   2.70
# 16                  0.00                   0.0  ...                   2.35
# 17                  0.00                   0.0  ...                   2.25
# 18                  0.00                   0.0  ...                   1.65
# 19                  0.00                   0.0  ...                   2.65
# 20                  0.00                   0.0  ...                   2.70
# 21                  1.00                   0.0  ...                   1.87
# 22                  3.00                   3.0  ...                   1.95
# 23                  3.00                   0.0  ...                   2.35
# 24                  3.00                   3.0  ...                   2.30
# 25                  0.00                   0.0  ...                   1.95
# 26                  0.00                   0.0  ...                   3.10
# 27                  0.00                   0.0  ...                   3.70
# 28                  1.00                   3.0  ...                   2.35
# 29                  1.00                   3.0  ...                   3.10
# 30                  0.00                   1.0  ...                   2.55
# 31                  0.00                   1.0  ...                   1.87
# 32                  1.00                   1.0  ...                   2.20
# 33                  1.00                   0.0  ...                   2.35
# 34                  3.00                   0.0  ...                   1.71
# 35                  3.00                   0.0  ...                   2.20
# 36                  3.00                   0.0  ...                   2.25
# 37                  3.00                   1.0  ...                   2.15
# 38                  3.00                   0.0  ...                   1.95
# 39                  0.00                   1.0  ...                   2.50
# 40                  1.00                   3.0  ...                   1.83
# 41                  0.00                   0.5  ...                   3.10
# 42                  3.00                   0.0  ...                   2.60
# 43                  3.00                   1.5  ...                   2.45
# 44                  3.00                   0.0  ...                   2.40
# 45                  0.50                   2.0  ...                   2.20
# 46                  2.00                   0.0  ...                   2.30
# 47                  3.00                   3.0  ...                   2.80
# 48                  3.00                   0.5  ...                   2.05
# 49                  3.00                   0.5  ...                   2.10
# 50                  3.00                   2.0  ...                   2.50
# 51                  1.50                   2.0  ...                   2.80
# 52                  0.67                   2.0  ...                   2.30
# 53                  0.50                   1.0  ...                   3.65
# 54                  0.00                   0.0  ...                   1.87
# 55                  0.50                   1.0  ...                   2.90
# 56                  0.50                   1.5  ...                   2.95
# 57                  3.00                   0.0  ...                   1.70
# 58                  1.50                   0.0  ...                   2.33
# 59                  1.00                   0.0  ...                   2.53
#
#     odds_ft_draw  odds_ft_away_team_win  odds_ft_over15  odds_ft_over25  \
# 0           3.10                   2.85            1.43            2.15
# 1           3.50                   4.20            1.35            1.95
# 2           3.25                   3.25            1.37            2.05
# 3           3.20                   3.30            1.39            2.10
# 4           3.15                   3.05            1.43            2.15
# 5           3.05                   3.20            1.47            2.25
# 6           3.35                   2.25            1.37            2.00
# 7           3.30                   3.95            1.43            2.15
# 8           3.05                   2.75            1.45            2.25
# 9           3.20                   3.25            1.38            2.23
# 10          3.30                   3.85            1.45            2.25
# 11          3.45                   2.25            1.47            2.40
# 12          3.35                   3.45            1.43            2.25
# 13          3.65                   4.45            1.30            1.80
# 14          3.20                   3.15            1.47            2.25
# 15          3.05                   2.65            1.47            2.25
# 16          3.15                   3.05            1.39            2.10
# 17          3.15                   3.25            1.45            2.25
# 18          3.80                   5.25            1.38            2.10
# 19          3.25                   2.60            1.40            2.10
# 20          3.05                   2.65            1.45            2.25
# 21          3.40                   4.25            1.43            2.20
# 22          3.05                   4.25            1.48            2.30
# 23          3.00                   3.20            1.47            2.20
# 24          3.00                   3.35            1.48            2.30
# 25          3.45                   3.80            1.34            1.91
# 26          3.00                   2.40            1.49            2.30
# 27          3.35                   2.00            1.39            2.10
# 28          3.15                   3.00            1.43            2.20
# 29          3.15                   2.30            1.36            2.00
# 30          3.25                   2.70            1.36            2.00
# 31          3.45                   4.10            1.39            2.10
# 32          3.15                   3.35            1.39            2.10
# 33          3.10                   3.15            1.38            2.05
# 34          3.45                   5.25            1.29            1.80
# 35          3.35                   3.20            1.33            1.95
# 36          3.20                   3.20            1.40            2.10
# 37          3.10                   3.60            1.38            2.05
# 38          3.55                   3.75            1.36            1.95
# 39          3.40                   2.70            1.34            1.95
# 40          3.35                   4.35            1.43            2.15
# 41          3.25                   2.30            1.45            2.25
# 42          3.00                   2.85            1.48            2.30
# 43          3.10                   2.95            1.51            2.40
# 44          3.10                   3.00            1.41            2.10
# 45          3.30                   3.20            1.43            2.20
# 46          3.25                   3.05            1.43            2.20
# 47          3.20                   2.45            1.37            2.00
# 48          3.35                   3.50            1.35            2.00
# 49          3.30                   3.45            1.39            2.10
# 50          3.20                   2.80            1.45            2.20
# 51          3.10                   2.60            1.45            2.25
# 52          3.05                   3.25            1.59            2.55
# 53          3.15                   2.10            1.56            2.50
# 54          3.65                   3.90            1.36            2.00
# 55          3.30                   2.40            1.38            2.05
# 56          3.05                   2.45            1.53            2.40
# 57          3.26                   4.36            1.36            2.15
# 58          3.20                   2.81            1.34            2.03
# 59          2.86                   2.60            1.45            2.32
#
#     odds_ft_over35  odds_ft_over45  odds_btts_yes odds_btts_no  \
# 0             3.65            7.00           1.95         1.83
# 1             3.30            6.50           1.91         1.87
# 2             3.35            6.50           1.87         1.91
# 3             3.45            6.75           1.91         1.87
# 4             3.60            7.00           1.95         1.83
# 5             3.90            7.75           2.05         1.77
# 6             3.35            6.50           1.87         1.91
# 7             3.80            7.50           2.05         1.77
# 8             3.85            7.50           2.00         1.80
# 9             4.05            8.25           2.10         1.71
# 10            3.90            7.50           2.05         1.74
# 11            4.75           10.00           2.10         1.67
# 12            3.80            7.50           2.05         1.74
# 13            2.90            5.00           1.80         1.95
# 14            3.90            7.75           2.05         1.74
# 15            3.90            7.50           2.00         1.77
# 16            3.45            6.75           1.87         1.91
# 17            3.80            7.75           2.05         1.74
# 18            3.65            7.00           2.10         1.69
# 19            3.55            6.75           1.91         1.87
# 20            3.80            7.25           2.00         1.77
# 21            3.75            7.25           2.05         1.77
# 22            4.05            8.25           2.10         1.71
# 23            3.80            7.25           1.95         1.83
# 24            3.95            7.75           2.00         1.77
# 25            3.15            6.00           1.83         1.91
# 26            4.00            7.75           2.05         1.74
# 27            3.55            6.75           2.00         1.80
# 28            3.75            7.25           2.00         1.80
# 29            3.20            6.00           1.80         2.00
# 30            3.30            6.25           1.83         1.95
# 31            3.55            6.75           1.91         1.87
# 32            3.45            6.75           1.91         1.87
# 33            3.35            6.25           1.83         1.95
# 34            2.90            5.25           1.77         2.00
# 35            3.15            6.00           1.80         1.95
# 36            3.50            6.75           1.91         1.87
# 37            3.40            6.50           1.83         1.91
# 38            3.25            6.00           1.91         1.87
# 39            3.20            6.00           1.80         1.95
# 40            3.75            7.25           2.05         1.74
# 41            3.80            7.50           2.05         1.74
# 42            3.95            7.50           2.00         1.77
# 43            4.25            8.75           2.15         1.67
# 44            3.50            6.75           1.91         1.87
# 45            3.80            7.50           1.95         1.80
# 46            3.70            7.25           2.00         1.80
# 47            3.30            6.25           1.83         1.95
# 48            3.25            6.00           1.83         1.95
# 49            3.50            7.00           1.95         1.80
# 50            3.80            7.25           2.00         1.80
# 51            3.85            7.75           2.05         1.77
# 52            4.75            9.50           2.25         1.61
# 53            4.50            9.25           2.25         1.62
# 54            3.40            6.50           1.95         1.83
# 55            3.40            6.50           1.87         1.91
# 56            4.20            8.25           2.15         1.69
# 57            3.75            7.25           2.10         1.69
# 58            3.40            5.75           1.80         2.00
# 59            4.05            8.00           2.05         1.74
#
#                                          stadium_name
# 0                       St James Park (Exeter- Devon)
# 1   The Fully Charged New Lawn (Nailsworth- Glouce...
# 2     EnviroVent Stadium (Harrogate- North Yorkshire)
# 3           Victoria Park (Hartlepool- County Durham)
# 4       One Call Stadium (Mansfield- Nottinghamshire)
# 5      Sixfields Stadium (Northampton- East Midlands)
# 6          Boundary Park (Oldham- Greater Manchester)
# 7   The Peninsula Stadium (Salford- Greater Manche...
# 8                    Sands Venue Stadium (Scunthorpe)
# 9        The Lamex Stadium (Stevenage- Hertfordshire)
# 10              Prenton Park (Birkenhead- Merseyside)
# 11                   Brunton Park (Carlisle- Cumbria)
# 12  The Dunes Hotel Stadium (Barrow-in-Furness- Cu...
# 13  The Utilita Energy Stadium (Bradford- West Yor...
# 14        Memorial Stadium (Bristol- Gloucestershire)
# 15     JobServe Community Stadium (Colchester- Essex)
# 16                  The Breyer Group Stadium (London)
# 17          Vale Park (Stoke-on-Trent- Staffordshire)
# 18     Crown Oil Arena (Rochdale- Greater Manchester)
# 19             The County Ground (Swindon- Wiltshire)
# 20           Banks's Stadium (Walsall- West Midlands)
# 21  The Peninsula Stadium (Salford- Greater Manche...
# 22      One Call Stadium (Mansfield- Nottinghamshire)
# 23  The Dunes Hotel Stadium (Barrow-in-Furness- Cu...
# 24  The Utilita Energy Stadium (Bradford- West Yor...
# 25        Memorial Stadium (Bristol- Gloucestershire)
# 26     JobServe Community Stadium (Colchester- Essex)
# 27  The People's Pension Stadium (Crawley- West Su...
# 28          Vale Park (Stoke-on-Trent- Staffordshire)
# 29     Crown Oil Arena (Rochdale- Greater Manchester)
# 30             The County Ground (Swindon- Wiltshire)
# 31           Banks's Stadium (Walsall- West Midlands)
# 32                   Brunton Park (Carlisle- Cumbria)
# 33                      St James Park (Exeter- Devon)
# 34  The Fully Charged New Lawn (Nailsworth- Glouce...
# 35    EnviroVent Stadium (Harrogate- North Yorkshire)
# 36          Victoria Park (Hartlepool- County Durham)
# 37      One Call Stadium (Mansfield- Nottinghamshire)
# 38     Sixfields Stadium (Northampton- East Midlands)
# 39         Boundary Park (Oldham- Greater Manchester)
# 40  The Peninsula Stadium (Salford- Greater Manche...
# 41                   Sands Venue Stadium (Scunthorpe)
# 42       The Lamex Stadium (Stevenage- Hertfordshire)
# 43              Prenton Park (Birkenhead- Merseyside)
# 44                  The Breyer Group Stadium (London)
# 45     Crown Oil Arena (Rochdale- Greater Manchester)
# 46  The Dunes Hotel Stadium (Barrow-in-Furness- Cu...
# 47  The People's Pension Stadium (Crawley- West Su...
# 48  The Fully Charged New Lawn (Nailsworth- Glouce...
# 49    EnviroVent Stadium (Harrogate- North Yorkshire)
# 50          Victoria Park (Hartlepool- County Durham)
# 51                  The Breyer Group Stadium (London)
# 52  The Peninsula Stadium (Salford- Greater Manche...
# 53                   Sands Venue Stadium (Scunthorpe)
# 54             VBS Community Stadium (Sutton- Surrey)
# 55             The County Ground (Swindon- Wiltshire)
# 56           Banks's Stadium (Walsall- West Midlands)
# 57  The Utilita Energy Stadium (Bradford- West Yor...
# 58        Memorial Stadium (Bristol- Gloucestershire)
# 59                   Brunton Park (Carlisle- Cumbria)
#
# [60 rows x 64 columns]

# %%
xg_view = games[['home_team_name', 'away_team_name', 'team_a_xg', 'team_b_xg', 'home_team_goal_count', 'away_team_goal_count']]
xg_view
# Out:
#          home_team_name       away_team_name  team_a_xg  team_b_xg  \
# 0           Exeter City        Bradford City       1.63       1.68
# 1   Forest Green Rovers        Sutton United       1.46       1.17
# 2        Harrogate Town             Rochdale       2.17       1.66
# 3     Hartlepool United         Crawley Town       1.36       0.80
# 4        Mansfield Town       Bristol Rovers       1.86       0.66
# 5      Northampton Town            Port Vale       1.12       1.22
# 6       Oldham Athletic       Newport County       0.70       1.02
# 7          Salford City        Leyton Orient       1.86       1.20
# 8     Scunthorpe United         Swindon Town       1.33       1.81
# 9             Stevenage               Barrow       1.27       1.40
# 10      Tranmere Rovers              Walsall       1.29       2.01
# 11      Carlisle United    Colchester United       1.84       1.18
# 12               Barrow    Hartlepool United       1.11       1.54
# 13        Bradford City      Oldham Athletic       1.64       1.45
# 14       Bristol Rovers            Stevenage       0.69       0.95
# 15    Colchester United     Northampton Town       1.59       0.79
# 16        Leyton Orient          Exeter City       1.31       1.11
# 17            Port Vale      Tranmere Rovers       1.54       1.21
# 18             Rochdale    Scunthorpe United       1.41       1.28
# 19         Swindon Town      Carlisle United       1.12       1.53
# 20              Walsall  Forest Green Rovers       1.09       1.66
# 21         Salford City        Sutton United       1.86       1.22
# 22       Mansfield Town       Newport County       1.03       1.22
# 23               Barrow          Exeter City       1.25       0.84
# 24        Bradford City            Stevenage       2.36       1.25
# 25       Bristol Rovers      Oldham Athletic       1.63       1.09
# 26    Colchester United       Mansfield Town       1.45       2.11
# 27         Crawley Town         Salford City       1.41       1.49
# 28            Port Vale      Carlisle United       1.31       1.52
# 29             Rochdale  Forest Green Rovers       1.35       1.38
# 30         Swindon Town      Tranmere Rovers       1.71       1.37
# 31              Walsall    Scunthorpe United       1.63       1.38
# 32      Carlisle United        Leyton Orient       1.23       0.80
# 33          Exeter City       Bristol Rovers       2.30       2.19
# 34  Forest Green Rovers         Crawley Town       2.25       1.31
# 35       Harrogate Town               Barrow       1.66       1.58
# 36    Hartlepool United              Walsall       1.51       0.81
# 37       Mansfield Town        Bradford City       2.10       1.38
# 38     Northampton Town             Rochdale       1.51       1.60
# 39      Oldham Athletic    Colchester United       1.60       1.57
# 40         Salford City         Swindon Town       1.62       0.94
# 41    Scunthorpe United        Sutton United       0.99       1.87
# 42            Stevenage            Port Vale       1.83       1.45
# 43      Tranmere Rovers       Newport County       1.58       1.45
# 44        Leyton Orient       Harrogate Town       0.90       0.96
# 45             Rochdale    Colchester United       1.66       1.41
# 46               Barrow       Bristol Rovers       1.16       1.50
# 47         Crawley Town     Northampton Town       1.21       1.74
# 48  Forest Green Rovers            Port Vale       1.00       1.32
# 49       Harrogate Town          Exeter City       1.89       1.59
# 50    Hartlepool United      Carlisle United       1.35       0.87
# 51        Leyton Orient        Bradford City       1.81       0.91
# 52         Salford City       Newport County       1.70       1.73
# 53    Scunthorpe United      Tranmere Rovers       1.41       0.89
# 54        Sutton United      Oldham Athletic       1.36       1.43
# 55         Swindon Town       Mansfield Town       1.24       1.78
# 56              Walsall            Stevenage       0.99       1.10
# 57        Bradford City              Walsall       0.00       0.00
# 58       Bristol Rovers         Crawley Town       0.00       0.00
# 59      Carlisle United         Salford City       0.00       0.00
#
#     home_team_goal_count  away_team_goal_count
# 0                      0                     0
# 1                      2                     1
# 2                      3                     2
# 3                      1                     0
# 4                      2                     1
# 5                      1                     0
# 6                      0                     1
# 7                      1                     1
# 8                      1                     3
# 9                      1                     0
# 10                     1                     0
# 11                     0                     0
# 12                     3                     2
# 13                     2                     1
# 14                     0                     2
# 15                     0                     1
# 16                     3                     0
# 17                     0                     0
# 18                     0                     0
# 19                     1                     2
# 20                     1                     3
# 21                     0                     0
# 22                     2                     1
# 23                     0                     0
# 24                     4                     1
# 25                     1                     0
# 26                     1                     1
# 27                     2                     1
# 28                     0                     0
# 29                     1                     2
# 30                     0                     0
# 31                     1                     1
# 32                     1                     1
# 33                     4                     1
# 34                     6                     3
# 35                     2                     1
# 36                     2                     0
# 37                     2                     3
# 38                     1                     3
# 39                     1                     2
# 40                     0                     1
# 41                     1                     1
# 42                     1                     1
# 43                     0                     1
# 44                     0                     2
# 45                     1                     1
# 46                     1                     1
# 47                     0                     0
# 48                     0                     2
# 49                     1                     1
# 50                     2                     1
# 51                     2                     0
# 52                     3                     0
# 53                     1                     0
# 54                     1                     2
# 55                     1                     0
# 56                     1                     0
# 57                     0                     0
# 58                     0                     0
# 59                     0                     0

# %% [markdown]
# # Goal Analysis

# %%
season_goal_total = games['total_goal_count'].sum()
season_1h_goal_total = games['total_goals_at_half_time'].sum()
percent_goals_1h = ((season_1h_goal_total)/(season_goal_total)) * 100

# %%
print(f'There were {season_goal_total} goals scored this season')
# Out:
# There were 26 goals scored this season

# %%
print(f'There were {season_1h_goal_total} goals scored in the 1H this season, ')
# Out:
# There were 11 goals scored in the 1H this season,

# %%
round(season_1h_goal_total/season_goal_total, 2)
#% of first half goals
# Out:
# 0.42

# %%
games['total_goals_at_half_time'].count()
# Out:
# 12

# %%
games['total_goals_at_half_time'].value_counts()
# Out:
# 0    5
# 1    4
# 2    2
# 3    1
# Name: total_goals_at_half_time, dtype: int64

# %% [markdown]
# # Adding more columns

# %%
games['home_xg'] = ""
games['away_xg'] = ""
games['home_xg_against'] = ""
games['away_xg_against'] = ""
games['home_total_corners'] = ""
games['away_total_corners'] = ""

# Creating new columns where our data will go

# %% [markdown]
# Let's write a function to help fill xg in our games df

# %%
xg_stats = team_stats[['common_name', 'xg_for_avg_overall']]
corner_stats = team_stats[['common_name', 'corners_per_match']]
xga_stats = team_stats[['common_name', 'xg_against_avg_overall']]

xga_stats
# Out:
#              common_name  xg_against_avg_overall
# 0             Stoke City                    0.85
# 1   West Bromwich Albion                    0.55
# 2          Middlesbrough                    0.83
# 3        AFC Bournemouth                    1.08
# 4              Hull City                    1.08
# 5           Swansea City                    1.27
# 6    Queens Park Rangers                    1.18
# 7           Cardiff City                    0.82
# 8                 Fulham                    0.66
# 9        Birmingham City                    0.79
# 10          Bristol City                    0.92
# 11     Preston North End                    0.82
# 12     Nottingham Forest                    1.04
# 13          Derby County                    1.11
# 14              Barnsley                    1.07
# 15      Blackburn Rovers                    1.22
# 16     Huddersfield Town                    1.17
# 17               Reading                    1.42
# 18             Blackpool                    1.40
# 19              Millwall                    1.02
# 20         Coventry City                    0.90
# 21   Peterborough United                    1.12
# 22      Sheffield United                    0.74
# 23            Luton Town                    1.20

# %%
xg_stats = dict(xg_stats.values)
corner_stats = dict(corner_stats.values)
xga_stats = dict(xga_stats.values)

#By making this into dictionaries, it will be easier to call them/update them with the function

# %%
def fill_stats(team):
    games['home_xg'] = np.where(games['home_team_name'] == team, xg_stats[team], games['home_xg'])
    games['away_xg'] = np.where(games['away_team_name'] == team, xg_stats[team], games['away_xg'])
    games['home_xg_against'] = np.where(games['home_team_name'] == team, xga_stats[team], games['home_xg_against'])
    games['away_xg_against'] = np.where(games['away_team_name'] == team, xga_stats[team], games['away_xg_against'])
    games['home_total_corners'] = np.where(games['home_team_name'] == team, corner_stats[team], games['home_total_corners'])
    games['away_total_corners'] = np.where(games['away_team_name'] == team, corner_stats[team], games['away_total_corners'])
    
#Function to put team stats into games dataframe

# %%
fill_stats('Fulham')
fill_stats('Blackburn Rovers')
fill_stats('West Bromwich Albion')
fill_stats('Queens Park Rangers')
fill_stats('AFC Bournemouth')
fill_stats('Middlesbrough')
fill_stats('Barnsley')
fill_stats('Millwall')
fill_stats('Sheffield United')
fill_stats('Reading')
fill_stats('Cardiff City')
fill_stats('Nottingham Forest')
fill_stats('Hull City')
fill_stats('Blackpool')
fill_stats('Luton Town')
fill_stats('Stoke City')
fill_stats('Swansea City')
fill_stats('Derby County')
fill_stats('Huddersfield Town')
fill_stats('Preston North End')
fill_stats('Coventry City')
fill_stats('Peterborough United')
fill_stats('Birmingham City')
fill_stats('Bristol City')

#Reading in stats

# %% [markdown]
# # Some more EDA

# %% [markdown]
# Let's write a function to help fill xg in our games df

# %%
games['home_xg'] = ""
games['away_xg'] = ""
games['home_xg_against'] = ""
games['away_xg_against'] = ""
games['home_total_corners'] = ""
games['away_total_corners'] = ""

# Creating new columns where our data will go



xg_stats = team_stats[['common_name', 'xg_for_avg_overall']]
corner_stats = team_stats[['common_name', 'corners_per_match']]
xga_stats = team_stats[['common_name', 'xg_against_avg_overall']]

xga_stats.head()

xg_stats = dict(xg_stats.values)
corner_stats = dict(corner_stats.values)
xga_stats = dict(xga_stats.values)

#By making this into dictionaries, it will be easier to call them/update them with the function

def fill_stats(team):
    games['home_xg'] = np.where(games['home_team_name'] == team, xg_stats[team], games['home_xg'])
    games['away_xg'] = np.where(games['away_team_name'] == team, xg_stats[team], games['away_xg'])
    games['home_xg_against'] = np.where(games['home_team_name'] == team, xga_stats[team], games['home_xg_against'])
    games['away_xg_against'] = np.where(games['away_team_name'] == team, xga_stats[team], games['away_xg_against'])
    games['home_total_corners'] = np.where(games['home_team_name'] == team, corner_stats[team], games['home_total_corners'])
    games['away_total_corners'] = np.where(games['away_team_name'] == team, corner_stats[team], games['away_total_corners'])
    
#Function to put team stats into games dataframe

fill_stats('Fulham')
fill_stats('Blackburn Rovers')
fill_stats('West Bromwich Albion')
fill_stats('Queens Park Rangers')
fill_stats('AFC Bournemouth')
fill_stats('Middlesbrough')
fill_stats('Barnsley')
fill_stats('Millwall')
fill_stats('Sheffield United')
fill_stats('Reading')
fill_stats('Cardiff City')
fill_stats('Nottingham Forest')
fill_stats('Hull City')
fill_stats('Blackpool')
fill_stats('Luton Town')
fill_stats('Stoke City')
fill_stats('Swansea City')
fill_stats('Derby County')
fill_stats('Huddersfield Town')
fill_stats('Preston North End')
fill_stats('Coventry City')
fill_stats('Peterborough United')
fill_stats('Birmingham City')
fill_stats('Bristol City')

#Reading in stats

# Some more EDA

# %% [markdown]
# # Over/Under 2.5?

# %%
games['over/under'] = np.where(games['home_team_goal_count'] + games['away_team_goal_count'] > 2.5, 1, 0)
# Adding column 0 represents under 2.5, 1 represents over 2.5

# %%
games['over/under'].value_counts()
# Out:
# 0    7
# 1    5
# Name: over/under, dtype: int64

# %% [markdown]
# # xG Over/Under 2.5?

# %%
games['xg_over/under'] = np.where(games['team_a_xg'] + games['team_b_xg'] > 2.99, 1, 0)
# Adding column 0 represents under 2.5, 1 represents over 2.5
games['xg_over/under_1.99'] = np.where(games['team_a_xg'] + games['team_b_xg'] > 1.99, 1, 0)
# Adding column 0 represents under 1.5, 1 represents over 1.5

# %%
games['xg_over/under'].value_counts()
# Out:
# 0    7
# 1    5
# Name: xg_over/under, dtype: int64

# %%
games['xg_over/under_1.99'].value_counts()
# Out:
# 1    11
# 0     1
# Name: xg_over/under_1.99, dtype: int64

# %% [markdown]
# # First Week

# %%
games['over/under_1.5'] = np.where(games['home_team_goal_count'] + games['away_team_goal_count'] > 1.5, 1, 0)
# Adding column 0 represents under 1.5, 1 represents over 1.5

# %%
first_matchweek = games[0:12]

# %%
first_matchweek['over/under'].value_counts()
# Out:
# 0    7
# 1    5
# Name: over/under, dtype: int64

# %%
first_matchweek['over/under_1.5'].value_counts()
# Out:
# 1    9
# 0    3
# Name: over/under_1.5, dtype: int64

# %%
first_matchweek['xg_over/under'].value_counts()
# Out:
# 0    7
# 1    5
# Name: xg_over/under, dtype: int64

# %%
first_matchweek['xg_over/under_1.99'].value_counts()
# Out:
# 1    11
# 0     1
# Name: xg_over/under_1.99, dtype: int64

# %%
games['home_team_goal_count_half_time'].sum()
# Out:
# 7

# %%
games['away_team_goal_count_half_time'].sum()
# Out:
# 4

# %% [markdown]
# # Let's take out the final week now and check percentage

# %%
first_41 = games[0:540]
first_41['over/under'].value_counts()
# Out:
# 0    7
# 1    5
# Name: over/under, dtype: int64

# %%
217/540
# Percentage of games that went over
# Out:
# 0.40185185185185185

# %% [markdown]
# # When were these goals scored?

# %% [markdown]
# Second half stoppage time goals will start at 91 i.e. 90+1 will be 91
# First half stoppage time goals will start at 100 i.e. 45+1 = 110 ----

# %% [markdown]
# Change stoppage time goals so we can cast them as floats

# %%
goal_timings = goal_timings.replace(to_replace="90'1", value = "91")
goal_timings = goal_timings.replace(to_replace="90'2", value = "92")
goal_timings = goal_timings.replace(to_replace="90'3", value = "93")
goal_timings = goal_timings.replace(to_replace="90'4", value = "94")
goal_timings = goal_timings.replace(to_replace="90'5", value = "95")
goal_timings = goal_timings.replace(to_replace="90'6", value = "96")
goal_timings = goal_timings.replace(to_replace="90'7", value = "97")
goal_timings = goal_timings.replace(to_replace="90'8", value = "98")
goal_timings = goal_timings.replace(to_replace="90'9", value = "99")
goal_timings = goal_timings.replace(to_replace="90'10", value = "100")
goal_timings = goal_timings.replace(to_replace="90'11", value = "101")
goal_timings = goal_timings.replace(to_replace="90'12", value = "102")
goal_timings = goal_timings.replace(to_replace="45'1", value = "110")
goal_timings = goal_timings.replace(to_replace="45'2", value = "111")
goal_timings = goal_timings.replace(to_replace="45'3", value = "112")
goal_timings = goal_timings.replace(to_replace="45'4", value = "113")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-e20ea993df15> in <module>
# ----> 1 goal_timings = goal_timings.replace(to_replace="90'1", value = "91")
#       2 goal_timings = goal_timings.replace(to_replace="90'2", value = "92")
#       3 goal_timings = goal_timings.replace(to_replace="90'3", value = "93")
#       4 goal_timings = goal_timings.replace(to_replace="90'4", value = "94")
#       5 goal_timings = goal_timings.replace(to_replace="90'5", value = "95")
#
# NameError: name 'goal_timings' is not defined

# %%
goal_timings['All_goal_timings'] = goal_timings['All_goal_timings'].astype('int')

# %%
timing_totals = goal_timings['All_goal_timings'].value_counts()
timing_totals = pd.DataFrame(timing_totals)

# %%
timing_totals = timing_totals.rename_axis("minute", axis="columns")
timing_totals = timing_totals.rename(columns={"All_goal_timings":"count"})

# %%
timing_totals['section'] = ""
timing_totals.head()

# %% [markdown]
# # In how many games did a team have more xG but lose?
